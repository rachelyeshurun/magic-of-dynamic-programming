# %% [markdown]
# # Experiments ...
# __By Rachel Yeshurun, June 2020__

# %% [markdown]
# The following code cell is saved after run

# %%
2*3
# Out:
# 6

# %% [markdown]
# The following video code is saved after run

# %%
from IPython.display import Image
Image("../images/video_thumbnails/sum_youtube_screenshot.png")

from IPython.display import YouTubeVideo
YouTubeVideo('roqumrTB9g0')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('roqumrTB9g0')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('roqumrTB9g0')

from IPython.display import Image
Image("../images/video_thumbnails/sum_youtube_screenshot.png")

# %% [markdown]
# The following cell is run, input hidden, saved

# %%
2*3
# Out:
# 6

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('roqumrTB9g0')

# %% [markdown]
# This demonstrates the hack to 'embed' video using markdown behind a screenshot image of the video
#
# [![click to play video](../images/video_thumbnails/sum_n_numbers_small.png)](https://youtu.be/roqumrTB9g0?t=0s "click to play video")

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
#     .onoffswitch-inner:before {
#         content: "Hide Solution";
#         padding-left: 10px;
#         background-color: #94A7C1; color: #FFFFFF;
#        }
#
#     .onoffswitch-inner:after {
#         content: "Show Solution";
#         padding-right: 10px;
#         background-color: #94A7C1; color: #999999;
#         text-align: right;
#     }

# %% [markdown]
# This notebook is based on the article: _Towards a better way to teach dynamic programming_ (Forišek, 2015)

# %% [markdown]
# The answer is 3

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-ece881bb48df> in <module>
# ----> 1 import plotly.express as px
#       2 df = px.data.iris()
#       3 fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
#       4               color='species')
#       5 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'
